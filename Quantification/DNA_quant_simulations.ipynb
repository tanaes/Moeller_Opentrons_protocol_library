# %%
from opentrons.simulate import simulate, format_runlog

# %% [markdown]
# ## Single plate quantification

# %%
protocol_file = open('./DNA_quant_one_plate.py', 'r')

runlog, _bundle = simulate(protocol_file)

protocol_file.close()

# %%
print(format_runlog(runlog))
# Out:
# Distributing 38.0 from A1 of reagents on 6 to A1 of assay on 5
# 	Transferring 38.0 from A1 of reagents on 6 to A1 of assay on 5
# 		Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 1
# 		Logs from this command:
# 		WARNING (robot_configs): /Users/jgs286/.opentrons/deck_calibration.json not found. Loading defaults
# 		WARNING (robot_configs): /Users/jgs286/.opentrons/robot_settings.json not found. Loading defaults
# 		Aspirating 276.0 uL from A1 of reagents on 6 at 1.0 speed
# 		Dispensing 38.0 uL into A1 of assay on 5 at 1.0 speed
# 		Dispensing 38.0 uL into A2 of assay on 5 at 1.0 speed
# 		Dispensing 38.0 uL into A3 of assay on 5 at 1.0 speed
# 		Dispensing 38.0 uL into A4 of assay on 5 at 1.0 speed
# 		Dispensing 38.0 uL into A5 of assay on 5 at 1.0 speed
# 		Dispensing 38.0 uL into A6 of assay on 5 at 1.0 speed
# 		Dispensing 38.0 uL into A7 of assay on 5 at 1.0 speed
# 		Blowing out at A1 of Opentrons Fixed Trash on 12
# ...

# %% [markdown]
# ## Four plate quantification

# %%
protocol_file = open('./DNA_quant_four_plates.py', 'r')

runlog, _bundle = simulate(protocol_file)

protocol_file.close()
# Out:
# namedtuple_Point:1: RuntimeWarning: coroutine 'API.get_attached_instruments' was never awaited
# ...

# %%
print(format_runlog(runlog))
# Out:
# Distributing 38.0 from A1 of reagents on 3 to A1 of assay on 9
# 	Transferring 38.0 from A1 of reagents on 3 to A1 of assay on 9
# 		Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 6
# 		Logs from this command:
# 		WARNING (robot_configs): /Users/jgs286/.opentrons/deck_calibration.json not found. Loading defaults
# 		WARNING (robot_configs): /Users/jgs286/.opentrons/robot_settings.json not found. Loading defaults
# 		Aspirating 276.0 uL from A1 of reagents on 3 at 1.0 speed
# 		Dispensing 38.0 uL into A1 of assay on 9 at 1.0 speed
# 		Dispensing 38.0 uL into B1 of assay on 9 at 1.0 speed
# 		Dispensing 38.0 uL into A2 of assay on 9 at 1.0 speed
# 		Dispensing 38.0 uL into B2 of assay on 9 at 1.0 speed
# 		Dispensing 38.0 uL into A3 of assay on 9 at 1.0 speed
# 		Dispensing 38.0 uL into B3 of assay on 9 at 1.0 speed
# 		Dispensing 38.0 uL into A4 of assay on 9 at 1.0 speed
# 		Blowing out at A1 of Opentrons Fixed Trash on 12
# ...

# %% [markdown]
# ## Magnetic DNA extraction

# %%
protocol_file = open('../Extraction/magnetic_DNA_extraction.py', 'r')

runlog, _bundle = simulate(protocol_file)

protocol_file.close()

# %%
print(format_runlog(runlog))
# Out:
# Distributing 20.0 from A1 of reagents on 10 to A1 of transfer plate on 1
# 	Transferring 20.0 from A1 of reagents on 10 to A1 of transfer plate on 1
# 		Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 2
# 		Logs from this command:
# 		WARNING (robot_configs): /Users/jgs286/.opentrons/deck_calibration.json not found. Loading defaults
# 		WARNING (robot_configs): /Users/jgs286/.opentrons/robot_settings.json not found. Loading defaults
# 		Aspirating 70.0 uL from A1 of reagents on 10 at 1.0 speed
# 		Touching tip
# 		Dispensing 20.0 uL into A1 of transfer plate on 1 at 1.0 speed
# 		Touching tip
# 		Dispensing 20.0 uL into A2 of transfer plate on 1 at 1.0 speed
# 		Touching tip
# 		Dispensing 20.0 uL into A3 of transfer plate on 1 at 1.0 speed
# 		Touching tip
# 		Blowing out at A1 of Opentrons Fixed Trash on 12
# 		Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A1 of Opentrons 96 Filter Tip Rack 200 µL on 7
# ...
